# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plot_non_af=pd.read_csv('mimic_perform_non_af_002_data.csv')
x_values = plot_non_af['Time'][:1000]
y_values = plot_non_af['PPG'][:1000]

# Create a line graph
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Time')

# Customize the plot
plt.title('Normal PPG graph')
plt.xlabel('Time')
plt.ylabel('PPG')
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# SRC:https://en.wikipedia.org/wiki/Photoplethysmogram#/media/File:PPG.PNG

# %%
plot_af=pd.read_csv('mimic_perform_af_008_data.csv')
x_values = plot_af['Time'][:1000]
y_values = plot_af['PPG'][:1000]

# Create a line graph
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Time')

# Customize the plot
plt.title('PPG graph of Arrhythmia Patient')
plt.xlabel('Time')
plt.ylabel('PPG')
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# SRC: https://www.researchgate.net/figure/PPG-and-ECG-signals-for-an-AFib-case_fig1_330843441
